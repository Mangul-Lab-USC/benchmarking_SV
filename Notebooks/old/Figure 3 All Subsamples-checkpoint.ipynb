# %%
import pandas as pd
import allel
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#BALB_CJ file names need changing 
strain=['AKR_J','A_J','C3H_HeJ','CBA_J','DBA_2J','LP_J']
tool=['breakdancer',
#'clever',
'delly',
'gasv',
'gridss',
#'indelminer',
'lumpexpress',
#'mistrvar',
#'pindel',
#'platypus',
'popdel',
'smoove',
'sniffles']

# %%
df_del=pd.read_csv('../analysis_files/del_summary.csv')
non_del=pd.read_csv('../analysis_files/nondel_summary.csv')

# %%
df_del.head()
# Out:
#           tool strain  length flag  position  threshold  cov  n
# 0  breakdancer    A_J     356   FP  10158232          0  0.5  1
# 1  breakdancer    A_J     919   FP  11576623          0  0.5  1
# 2  breakdancer    A_J    3696   FP  19763412          0  0.5  1
# 3  breakdancer    A_J    4601   FP  20139734          0  0.5  1
# 4  breakdancer    A_J    8258   FP  20766145          0  0.5  1

# %%
non_del.head()
# Out:
#           tool strain  length flag  position  threshold  cov  n
# 0  breakdancer    A_J   22114   TN  37595335      10000  0.5  7
# 1  breakdancer    A_J   35326   TN  41489854       1000  0.5  2
# 2  breakdancer    A_J   22114   TN  37595335       1000  0.5  7
# 3  breakdancer    A_J   40385   TN  50557978       1000  0.5  9
# 4  breakdancer    A_J  174239   TN  37624530       1000  1.0  1

# %%
df_merge=pd.merge(df_del, non_del,on=['tool','threshold','strain'])
df_merge.head()
# Out:
#           tool strain  length_x flag_x  position_x  threshold  cov_x  n_x  \
# 0  breakdancer    A_J       326     TP    10568090      10000    0.5    7
# 1  breakdancer    A_J       326     TP    10568090      10000    0.5    7
# 2  breakdancer    A_J       326     TP    10568090      10000    0.5    7
# 3  breakdancer    A_J       326     TP    10568090      10000    0.5    7
# 4  breakdancer    A_J       326     TP    10568090      10000    0.5    7
#
#    length_y flag_y  position_y  cov_y  n_y
# 0     22114     TN    37595335    0.5    7
# 1    311673     TN    15527713    2.0    1
# 2     68429     TN    15846589    2.0    1
# 3     77773     TN    19985619    2.0    1
# 4     76080     TN    20063792    2.0    1

# %% [markdown]
# # Group Data

# %%
group_data_TP=df_del[df_del['flag'] == 'TP'].groupby(['tool','threshold','strain','n','cov'],as_index=False)['flag'].count()
group_data_TP=group_data_TP.rename(columns={"flag": "nTP"})


group_data_TP[pd.isnull(group_data_TP).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [tool, threshold, strain, n, cov, nTP]
# Index: []

# %%
group_data_FP=df_del[df_del['flag' == 'FP'].groupby(['tool','threshold','strain','n','cov'], as_index=False)['flag'].count()]
group_data_FP=group_data_FP.rename(columns={"flag":"nFP"})

group_data_FP[pd.isnull(group_data_FP).any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4b03aec7f75d> in <module>
# ...
