# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../Data/cpu.ram.stats/cpu_mouse.csv")

# %%
data
# Out:
#            Tool sample_name       coverage     time  memory(MB)  \
# 0   Breakdancer         A_J             1x     1.00     225.680
# 1   Breakdancer         A_J  full_coverage     1.00     225.676
# 2   Breakdancer     BALB_cJ             1x     2.00     310.918
# 3   Breakdancer     BALB_cJ  full_coverage     1.00     320.258
# 4          GASV         A_J             1x     6.00   10307.000
# 5          GASV         A_J  full_coverage   304.00   11104.000
# 6          GASV     BALB_cJ             1x     5.00   10307.000
# 7          GASV     BALB_cJ  full_coverage   551.00   12632.000
# 8        PopDEL         A_J             1x     2.68       6.572
# 9        PopDEL         A_J  full_coverage     9.05       9.320
# 10       PopDEL     BALB_cJ             1x     2.88       8.156
# 11       PopDEL     BALB_cJ  full_coverage    10.49       8.784
# 12        LUMPY         A_J             1x    11.86     244.272
# 13        LUMPY         A_J  full_coverage    95.71     244.456
# ...

# %%
# gasv takes the longest, the two samples show similar behavior
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="sample_name", y="time",data=data,hue='Tool',aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Sample', ylabel='CPU-time (seconds)',yscale="log")
g=sns.despine()
plt.savefig('../Figures/supplementary/mouse/cpu_memory/FigS20_time_sample.png')
plt.show(g)

# %%
# gasv takes the most memory, the two samples show similar behavior
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="sample_name", y="memory (GB)",data=data,hue='Tool',aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Sample', ylabel='Memory (GB)',yscale="log")
g=sns.despine()
plt.savefig('../Figures/supplementary/mouse/cpu_memory/FigS20_memory_sample.png')
plt.show(g)

# %%
#Time taken by 1x is negligible as compared to full coverage sample 
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="time",data=data,hue='coverage',aspect=3,kind='bar',capsize=.1,errwidth=3)
g.set(xlabel='Tools', ylabel='CPU-time (seconds)',yscale="log")
g=sns.despine()
plt.xticks(rotation=45)
plt.savefig('../Figures/supplementary/mouse/cpu_memory/FigS20_time_coverage.png')
plt.show(g)

# %%
#Memory for full coverage and 1x is comparable 
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="memory (GB)",data=data,hue='coverage',aspect=3,kind='bar',capsize=.1,errwidth=3)
g.set(xlabel='Tools', ylabel='Memory (GB)',yscale="log")
g=sns.despine()
plt.xticks(rotation=45)
plt.savefig('../Figures/supplementary/mouse/cpu_memory/FigS20_memory_coverage.png')
plt.show(g)

# %%
#only contains coverage from 1x 
data_1x=data.loc[data['coverage'] == "1x"]
#only contains coverage from 64x 
data_64x=data.loc[data['coverage'] == "full_coverage"]

# %%
data_1x
# Out:
#            Tool sample_name coverage    time  memory(MB)  \
# 0   Breakdancer         A_J       1x    1.00     225.680
# 2   Breakdancer     BALB_cJ       1x    2.00     310.918
# 4          GASV         A_J       1x    6.00   10307.000
# 6          GASV     BALB_cJ       1x    5.00   10307.000
# 8        PopDEL         A_J       1x    2.68       6.572
# 10       PopDEL     BALB_cJ       1x    2.88       8.156
# 12        LUMPY         A_J       1x   11.86     244.272
# 14        LUMPY     BALB_cJ       1x   13.89     244.612
# 16     MiStrVar         A_J       1x   57.37     902.812
# 18     MiStrVar     BALB_cJ       1x   68.09     983.292
# 20      Pindel          A_J       1x   19.00     856.203
# 22      Pindel      BALB_cJ       1x   22.00     856.602
# 24       CLEVER         A_J       1x   24.00     795.758
# 26       CLEVER     BALB_cJ       1x   27.00     795.758
# 28       GRIDDS         A_J       1x  376.90    4682.244
# ...

# %%
#Variation of time for 1x with tool
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="time",data=data_1x,aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools (1x Coverage)', ylabel='CPU-time (seconds)',yscale="log")
g=sns.despine()
plt.savefig('../Figures/supplementary/mouse/cpu_memory/FigS20_runtime_tools_1x.png')
plt.show(g)

# %%
#Variation of memory for 1x with tool
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="memory (GB)",data=data_1x,aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools (1x Coverage)', ylabel='Memory (GB)',yscale="log")
g=sns.despine()
plt.savefig('../Figures/supplementary/mouse/cpu_memory/FigS20_memory_tools_1x.png')
plt.show(g)

# %%
data_64x
# Out:
#            Tool sample_name       coverage     time  memory(MB)  \
# 1   Breakdancer         A_J  full_coverage     1.00     225.676
# 3   Breakdancer     BALB_cJ  full_coverage     1.00     320.258
# 5          GASV         A_J  full_coverage   304.00   11104.000
# 7          GASV     BALB_cJ  full_coverage   551.00   12632.000
# 9        PopDEL         A_J  full_coverage     9.05       9.320
# 11       PopDEL     BALB_cJ  full_coverage    10.49       8.784
# 13        LUMPY         A_J  full_coverage    95.71     244.456
# 15        LUMPY     BALB_cJ  full_coverage   114.47     244.564
# 17     MiStrVar         A_J  full_coverage  2939.84    3073.916
# 19     MiStrVar     BALB_cJ  full_coverage  3387.34    4419.696
# 21      Pindel          A_J  full_coverage   990.00    1236.000
# 23      Pindel      BALB_cJ  full_coverage  1047.00    1403.000
# 25       CLEVER         A_J  full_coverage  3510.00     872.949
# 27       CLEVER     BALB_cJ  full_coverage  1915.00     886.273
# ...

# %%
#Variation of time for 1x with tool
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="time",data=data_64x,aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools (64x Coverage)', ylabel='CPU-time (seconds)',yscale="log")
g=sns.despine()
plt.savefig('../Figures/supplementary/mouse/cpu_memory/FigS20_runtime_tools_64x.png')
plt.show(g)

# %%
#Variation of memory for 1x with tool
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="memory (GB)",data=data_64x,aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools (64x Coverage)', ylabel='Memory (GB)',yscale="log")
g=sns.despine()
plt.savefig('../Figures/supplementary/mouse/cpu_memory/FigS20_memory_tools_64x.png')
plt.show(g)
