# %% [markdown]
# # Concatenating all tools and strains at threshold 0, 10, 100, 1000, and 10K

# %%
import os
import allel
import pandas as pd


strain=['A_J','AKR_J','BALB_CJ','CBA_J','C3H_HeJ','DBA_2J','LP_J']

tools=['BioGraph*',
'breakdancer',
'clever',
'delly',
'gasv',
'gridss',
'indelminer',
'lumpexpress',
'mistrvar',
'pindel',
'platypus',
'popdel',
'rdxplorer',
'smoove',
'sniffles']

# %% [markdown]
# ## 0 bp Threshold

# %%
#0 threshold deletions

th=0
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_0 = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])
for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.vcf'
        
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_0 = pd.concat([df_current, df_0],ignore_index=True)   
        
        else:
            print("Empty File: " + file)
            
df_0.head()
# Out:
# /Users/angelalu/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py:1745: UserWarning: multiple INFO headers for 'SVLEN'
#   warnings.warn('multiple INFO headers for %r' % k)
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/0t/deletions/nf_0t.pindel.BALB_CJ.chr19.100p_sorted.modified.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/0t/deletions/nf_0t.platypus.BALB_CJ.chr19.100p_sorted.modified.vcf
#        tool strain    length flag  position threshold
# 0  sniffles   LP_J      1725   FP   6055203         0
# 1  sniffles   LP_J        78   FP  17072687         0
# 2  sniffles   LP_J  34582728   FP  17098523         0
# 3  sniffles   LP_J        48   FP  17201451         0
# 4  sniffles   LP_J       114   FP  17231867         0

# %%
#0 threshold non-deletions
import os

th=0
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_0_nondel = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])
for s in strain:
    for t in tools:
        
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/non-deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.nondel.vcf'
        
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            print ("----")
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_0_nondel = pd.concat([df_current, df_0_nondel],ignore_index=True)   
            
        #else:
            #print("Empty File: " + file)
        
df_0_nondel.head()
# Out:
# Empty DataFrame
# Columns: [tool, strain, length, flag, position, threshold]
# Index: []

# %% [markdown]
# ## 10 bp Threshold

# %%
#10 threshold deletions
#missing files: pindel.BALB_CJ, and platypus.BALB_CJ

th=10     
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_10 = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])

for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.vcf'
        
        
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_10 = pd.concat([df_current, df_10],ignore_index=True)
            
        else:
            print("Empty File: " + file)
            
df_10.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2ce3b51ab1df> in <module>
#      11
#      12
# ---> 13         callset = allel.read_vcf(file,fields='*')
#      14         if callset!=None:
#      15             df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in read_vcf(input, fields, exclude_fields, rename_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length, log)
#     308         numbers=numbers, alt_number=alt_number, buffer_size=buffer_size,
#     309         chunk_length=chunk_length, fills=fills, region=region, tabix=tabix,
# --> 310         samples=samples, transformers=transformers
#     311     )
#     312
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in iter_vcf_chunks(input, fields, exclude_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length)
#    1142     # setup input stream
#    1143     stream = _setup_input_stream(input=input, region=region, tabix=tabix,
# -> 1144                                  buffer_size=buffer_size)
#    1145
#    1146     # setup iterator
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in _setup_input_stream(input, region, tabix, buffer_size)
#    1065     elif isinstance(input, str):
#    1066         # assume no compression
# -> 1067         fileobj = open(input, mode='rb', buffering=0)
#    1068         close = True
#    1069
#
# FileNotFoundError: [Errno 2] No such file or directory: '../raw_data/mouse/custom_vcf_fulldata/10t/deletions/nf_10t.pindel.BALB_CJ.chr19.100p_sorted.modified.vcf'

# %%
#10 threshold non-deletions
th=10     
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_10_nondel = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])

for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/non-deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.nondel.vcf'
        
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_10_nondel = pd.concat([df_current, df_10_nondel],ignore_index=True)
            
        else:
            print("Empty File: " + file)
            
df_10_nondel.head()
# Out:
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.gasv.A_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.indelminer.A_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.mistrvar.A_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.popdel.A_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.gasv.AKR_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.lumpexpress.AKR_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.mistrvar.AKR_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.rdxplorer.AKR_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.gasv.BALB_CJ.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.mistrvar.BALB_CJ.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.gasv.CBA_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.mistrvar.CBA_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.gasv.C3H_HeJ.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.indelminer.C3H_HeJ.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.popdel.C3H_HeJ.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.gasv.DBA_2J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.mistrvar.DBA_2J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.rdxplorer.DBA_2J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.gasv.LP_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.indelminer.LP_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.mistrvar.LP_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10t/non-deletions/nf_10t.rdxplorer.LP_J.chr19.100p_sorted.modified.nondel.vcf
#        tool strain  length flag  position threshold
# 0  sniffles   LP_J   28641   TN  22431541        10
# 1  sniffles   LP_J   19855   TN  26270409        10
# 2  sniffles   LP_J   40409   TN  28848778        10
# 3  sniffles   LP_J  167267   TN  32209571        10
# 4  sniffles   LP_J   40453   TN  50557877        10

# %% [markdown]
# ## 100 bp Threshold

# %%
#100 threshold deletions
#missing files: pindel.BALB_CJ, and platypus.BALB_CJ

df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_100 = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])

for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.vcf'
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_100 = pd.concat([df_current, df_100],ignore_index=True)
        
        else:
            print("Empty File: " + file)
            
df_100.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1f4434d15b4a> in <module>
#       8     for t in tools:
#       9         file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.vcf'
# ---> 10         callset = allel.read_vcf(file,fields='*')
#      11         if callset!=None:
#      12             df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in read_vcf(input, fields, exclude_fields, rename_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length, log)
#     308         numbers=numbers, alt_number=alt_number, buffer_size=buffer_size,
#     309         chunk_length=chunk_length, fills=fills, region=region, tabix=tabix,
# --> 310         samples=samples, transformers=transformers
#     311     )
#     312
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in iter_vcf_chunks(input, fields, exclude_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length)
#    1142     # setup input stream
#    1143     stream = _setup_input_stream(input=input, region=region, tabix=tabix,
# -> 1144                                  buffer_size=buffer_size)
#    1145
#    1146     # setup iterator
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in _setup_input_stream(input, region, tabix, buffer_size)
#    1065     elif isinstance(input, str):
#    1066         # assume no compression
# -> 1067         fileobj = open(input, mode='rb', buffering=0)
#    1068         close = True
#    1069
#
# FileNotFoundError: [Errno 2] No such file or directory: '../raw_data/mouse/custom_vcf_fulldata/10t/deletions/nf_10t.pindel.BALB_CJ.chr19.100p_sorted.modified.vcf'

# %%
#100 threshold non-deletions

th=100     
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_100_nondel = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])

for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/non-deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.nondel.vcf'
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_100_nondel = pd.concat([df_current, df_100_nondel],ignore_index=True)
            
        else:
            print("Empty File: " + file)
            
df_100_nondel.head()
# Out:
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/100t/non-deletions/nf_100t.lumpexpress.AKR_J.chr19.100p_sorted.modified.nondel.vcf
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/100t/non-deletions/nf_100t.indelminer.LP_J.chr19.100p_sorted.modified.nondel.vcf
#        tool strain  length flag  position threshold
# 0  sniffles   LP_J   24683   TN  21449705       100
# 1  sniffles   LP_J   21785   TN  22409688       100
# 2  sniffles   LP_J   28641   TN  22431541       100
# 3  sniffles   LP_J  261746   TN  22797608       100
# 4  sniffles   LP_J  149268   TN  23059703       100

# %% [markdown]
# ## 1000 bp Threshold

# %%
#1000 threshold deletions
#missing files: pindel.BALB_CJ, and platypus.BALB_CJ

th=1000    
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_1000 = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])

for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.vcf'
        
        
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_1000 = pd.concat([df_current, df_1000],ignore_index=True)
            
        else:
            print("Empty File: " + file)
           
df_1000.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-ce0ff16a3183> in <module>
#      11
#      12
# ---> 13         callset = allel.read_vcf(file,fields='*')
#      14         if callset!=None:
#      15             df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in read_vcf(input, fields, exclude_fields, rename_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length, log)
#     308         numbers=numbers, alt_number=alt_number, buffer_size=buffer_size,
#     309         chunk_length=chunk_length, fills=fills, region=region, tabix=tabix,
# --> 310         samples=samples, transformers=transformers
#     311     )
#     312
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in iter_vcf_chunks(input, fields, exclude_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length)
#    1142     # setup input stream
#    1143     stream = _setup_input_stream(input=input, region=region, tabix=tabix,
# -> 1144                                  buffer_size=buffer_size)
#    1145
#    1146     # setup iterator
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in _setup_input_stream(input, region, tabix, buffer_size)
#    1065     elif isinstance(input, str):
#    1066         # assume no compression
# -> 1067         fileobj = open(input, mode='rb', buffering=0)
#    1068         close = True
#    1069
#
# FileNotFoundError: [Errno 2] No such file or directory: '../raw_data/mouse/custom_vcf_fulldata/1000t/deletions/nf_1000t.pindel.BALB_CJ.chr19.100p_sorted.modified.vcf'

# %%
#1000 threshold non-deletions

th=1000    
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_1000_nondel = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])

for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/non-deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.nondel.vcf'
        
        
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_1000_nondel = pd.concat([df_current, df_1000_nondel],ignore_index=True)
            
        else:
            print("Empty File: " + file)
        
df_1000_nondel.head()
# Out:
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/1000t/non-deletions/nf_1000t.lumpexpress.AKR_J.chr19.100p_sorted.modified.nondel.vcf
#        tool strain  length flag  position threshold
# 0  sniffles   LP_J    2164   TN  18924303      1000
# 1  sniffles   LP_J  868204   TN  18926808      1000
# 2  sniffles   LP_J   24683   TN  21449705      1000
# 3  sniffles   LP_J   21785   TN  22409688      1000
# 4  sniffles   LP_J   28641   TN  22431541      1000

# %% [markdown]
# ## 10000 bp Threshold

# %%
#10000 threshold deletions
#missing files: pindel.BALB_CJ, and platypus.BALB_CJ

th=10000    
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_10000 = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])

for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.vcf'
        
        
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_10000 = pd.concat([df_current, df_10000],ignore_index=True)
        else:
            print("Empty File: " + file)
        
df_10000.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-b041771dd43c> in <module>
#      11
#      12
# ---> 13         callset = allel.read_vcf(file,fields='*')
#      14         if callset!=None:
#      15             df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in read_vcf(input, fields, exclude_fields, rename_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length, log)
#     308         numbers=numbers, alt_number=alt_number, buffer_size=buffer_size,
#     309         chunk_length=chunk_length, fills=fills, region=region, tabix=tabix,
# --> 310         samples=samples, transformers=transformers
#     311     )
#     312
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in iter_vcf_chunks(input, fields, exclude_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length)
#    1142     # setup input stream
#    1143     stream = _setup_input_stream(input=input, region=region, tabix=tabix,
# -> 1144                                  buffer_size=buffer_size)
#    1145
#    1146     # setup iterator
#
# ~/opt/anaconda3/lib/python3.7/site-packages/allel/io/vcf_read.py in _setup_input_stream(input, region, tabix, buffer_size)
#    1065     elif isinstance(input, str):
#    1066         # assume no compression
# -> 1067         fileobj = open(input, mode='rb', buffering=0)
#    1068         close = True
#    1069
#
# FileNotFoundError: [Errno 2] No such file or directory: '../raw_data/mouse/custom_vcf_fulldata/10000t/deletions/nf_10000t.pindel.BALB_CJ.chr19.100p_sorted.modified.vcf'

# %%
#10000 threshold non-deletions

th=10000    
df_current = pd.DataFrame(columns=['strain','length','flag','position','threshold'])
df_10000_nondel = pd.DataFrame(columns=['tool','strain','length','flag','position','threshold'])

for s in strain:
    for t in tools:
        file='../raw_data/mouse/custom_vcf_fulldata/'+str(th)+'t/non-deletions/nf_'+str(th)+'t.'+t+'.'+s+'.chr19.100p_sorted.modified.nondel.vcf'
        
        
        callset = allel.read_vcf(file,fields='*')
        if callset!=None:
            df_current = pd.DataFrame({'tool': t, 'strain': s, 'length': callset['variants/SVLEN'],'flag': callset['variants/FLAG'],'position': callset['variants/POS'],'threshold': th})
            df_10000_nondel = pd.concat([df_current, df_10000_nondel],ignore_index=True)
        else:
            print("Empty File: " + file)
           
        
df_10000_nondel.head()
# Out:
# Empty File: ../raw_data/mouse/custom_vcf_fulldata/10000t/non-deletions/nf_10000t.lumpexpress.AKR_J.chr19.100p_sorted.modified.nondel.vcf
#        tool strain  length flag  position threshold
# 0  sniffles   LP_J    2164   TN  18924303     10000
# 1  sniffles   LP_J  868204   TN  18926808     10000
# 2  sniffles   LP_J   37527   TN  20102302     10000
# 3  sniffles   LP_J   24683   TN  21449705     10000
# 4  sniffles   LP_J   69668   TN  22336470     10000

# %% [markdown]
# ## Concatenate

# %%
#removed df_0 and df_0_nondel for graphing purposes
pdList = [df_10, df_100,df_1000,df_10000, df_10_nondel, df_100_nondel,df_1000_nondel,df_10000_nondel]  # List of your dataframes
df_cat = pd.concat(pdList)

# %%
#output counts for TP, FP, TN rows are not the same as Varuni's; due to missing files?
group_data_TP=df_cat[df_cat['flag'] == 'TP'].groupby(['tool','threshold','strain'],as_index=False)['flag'].count()
group_data_TP=group_data_TP.rename(columns={"flag": "nTP"})
group_data_TP.shape
# Out:
# (112, 4)

# %%
group_data_FP=df_cat[df_cat['flag'] == 'FP'].groupby(['tool','threshold','strain'],as_index=False)['flag'].count()
group_data_FP=group_data_FP.rename(columns={"flag": "nFP"})
group_data_FP.shape
# Out:
# (117, 4)

# %%
group_data_TN=df_cat[df_cat['flag'] == 'TN'].groupby(['tool','threshold','strain'],as_index=False)['flag'].count()
group_data_TN=group_data_TN.rename(columns={"flag": "nTN"})
group_data_TN.shape
# Out:
# (394, 4)

# %%
#fill missing combinations with 0s
#removed 0 threshold group since it = 0 for all tools
for s in strain:
    for t in tools:
        for th in [10,100,1000,10000]:
            if not (((group_data_TP['tool'] == t) & (group_data_TP['strain'] == s) & (group_data_TP['threshold'] == th)).any()):
                group_data_TP = group_data_TP.append({'tool' : t , 'strain' : s,'threshold' : th,'nTP' : 0} , ignore_index=True)
group_data_TP.shape
# Out:
# (420, 4)

# %%
for s in strain:
    for t in tools:
        for th in [10,100,1000,10000]:
            if not (((group_data_FP['tool'] == t) & (group_data_FP['strain'] == s) & (group_data_FP['threshold'] == th)).any()):
                #group_data_FP = group_data_FP.append({'tool' : t , 'strain' : s,'threshold' : th,'nFP' : 0} , ignore_index=True)
                print (s,t,th)
group_data_FP.shape
# Out:
# A_J BioGraph* 100
# A_J breakdancer 100
# A_J clever 100
# A_J delly 100
# A_J gasv 100
# A_J gridss 100
# A_J indelminer 100
# A_J lumpexpress 100
# A_J mistrvar 100
# A_J pindel 100
# A_J platypus 100
# A_J popdel 100
# A_J rdxplorer 100
# A_J smoove 100
# A_J sniffles 100
# AKR_J BioGraph* 100
# AKR_J breakdancer 100
# AKR_J clever 100
# AKR_J delly 100
# AKR_J gasv 100
# AKR_J gridss 100
# AKR_J indelminer 100
# AKR_J lumpexpress 100
# AKR_J mistrvar 100
# AKR_J pindel 100
# AKR_J platypus 100
# AKR_J popdel 100
# AKR_J rdxplorer 100
# AKR_J smoove 100
# AKR_J sniffles 100
# BALB_CJ BioGraph* 100
# BALB_CJ breakdancer 100
# BALB_CJ clever 100
# BALB_CJ delly 100
# BALB_CJ gasv 100
# BALB_CJ gridss 100
# BALB_CJ indelminer 100
# BALB_CJ lumpexpress 100
# BALB_CJ mistrvar 100
# BALB_CJ pindel 10
# BALB_CJ pindel 100
# BALB_CJ pindel 1000
# BALB_CJ pindel 10000
# BALB_CJ platypus 10
# BALB_CJ platypus 100
# BALB_CJ platypus 1000
# BALB_CJ platypus 10000
# BALB_CJ popdel 10
# BALB_CJ popdel 100
# BALB_CJ popdel 1000
# BALB_CJ popdel 10000
# BALB_CJ rdxplorer 10
# BALB_CJ rdxplorer 100
# BALB_CJ rdxplorer 1000
# BALB_CJ rdxplorer 10000
# BALB_CJ smoove 10
# BALB_CJ smoove 100
# BALB_CJ smoove 1000
# BALB_CJ smoove 10000
# BALB_CJ sniffles 10
# BALB_CJ sniffles 100
# BALB_CJ sniffles 1000
# BALB_CJ sniffles 10000
# CBA_J BioGraph* 10
# CBA_J BioGraph* 100
# CBA_J BioGraph* 1000
# CBA_J BioGraph* 10000
# CBA_J breakdancer 10
# CBA_J breakdancer 100
# CBA_J breakdancer 1000
# CBA_J breakdancer 10000
# CBA_J clever 10
# CBA_J clever 100
# CBA_J clever 1000
# CBA_J clever 10000
# CBA_J delly 10
# CBA_J delly 100
# CBA_J delly 1000
# CBA_J delly 10000
# CBA_J gasv 10
# CBA_J gasv 100
# CBA_J gasv 1000
# CBA_J gasv 10000
# CBA_J gridss 10
# CBA_J gridss 100
# CBA_J gridss 1000
# CBA_J gridss 10000
# CBA_J indelminer 10
# CBA_J indelminer 100
# CBA_J indelminer 1000
# CBA_J indelminer 10000
# CBA_J lumpexpress 10
# CBA_J lumpexpress 100
# CBA_J lumpexpress 1000
# CBA_J lumpexpress 10000
# CBA_J mistrvar 10
# CBA_J mistrvar 100
# CBA_J mistrvar 1000
# CBA_J mistrvar 10000
# CBA_J pindel 10
# CBA_J pindel 100
# CBA_J pindel 1000
# CBA_J pindel 10000
# CBA_J platypus 10
# CBA_J platypus 100
# CBA_J platypus 1000
# CBA_J platypus 10000
# CBA_J popdel 10
# CBA_J popdel 100
# CBA_J popdel 1000
# CBA_J popdel 10000
# CBA_J rdxplorer 10
# CBA_J rdxplorer 100
# CBA_J rdxplorer 1000
# CBA_J rdxplorer 10000
# CBA_J smoove 10
# CBA_J smoove 100
# CBA_J smoove 1000
# CBA_J smoove 10000
# CBA_J sniffles 10
# CBA_J sniffles 100
# CBA_J sniffles 1000
# CBA_J sniffles 10000
# C3H_HeJ BioGraph* 10
# C3H_HeJ BioGraph* 100
# C3H_HeJ BioGraph* 1000
# C3H_HeJ BioGraph* 10000
# C3H_HeJ breakdancer 10
# C3H_HeJ breakdancer 100
# C3H_HeJ breakdancer 1000
# C3H_HeJ breakdancer 10000
# C3H_HeJ clever 10
# C3H_HeJ clever 100
# C3H_HeJ clever 1000
# C3H_HeJ clever 10000
# C3H_HeJ delly 10
# C3H_HeJ delly 100
# C3H_HeJ delly 1000
# C3H_HeJ delly 10000
# C3H_HeJ gasv 10
# C3H_HeJ gasv 100
# C3H_HeJ gasv 1000
# C3H_HeJ gasv 10000
# C3H_HeJ gridss 10
# C3H_HeJ gridss 100
# C3H_HeJ gridss 1000
# C3H_HeJ gridss 10000
# C3H_HeJ indelminer 10
# C3H_HeJ indelminer 100
# C3H_HeJ indelminer 1000
# C3H_HeJ indelminer 10000
# C3H_HeJ lumpexpress 10
# C3H_HeJ lumpexpress 100
# C3H_HeJ lumpexpress 1000
# C3H_HeJ lumpexpress 10000
# C3H_HeJ mistrvar 10
# C3H_HeJ mistrvar 100
# C3H_HeJ mistrvar 1000
# C3H_HeJ mistrvar 10000
# C3H_HeJ pindel 10
# C3H_HeJ pindel 100
# C3H_HeJ pindel 1000
# C3H_HeJ pindel 10000
# C3H_HeJ platypus 10
# C3H_HeJ platypus 100
# C3H_HeJ platypus 1000
# C3H_HeJ platypus 10000
# C3H_HeJ popdel 10
# C3H_HeJ popdel 100
# C3H_HeJ popdel 1000
# C3H_HeJ popdel 10000
# C3H_HeJ rdxplorer 10
# C3H_HeJ rdxplorer 100
# C3H_HeJ rdxplorer 1000
# C3H_HeJ rdxplorer 10000
# C3H_HeJ smoove 10
# C3H_HeJ smoove 100
# C3H_HeJ smoove 1000
# C3H_HeJ smoove 10000
# C3H_HeJ sniffles 10
# C3H_HeJ sniffles 100
# C3H_HeJ sniffles 1000
# C3H_HeJ sniffles 10000
# DBA_2J BioGraph* 10
# DBA_2J BioGraph* 100
# DBA_2J BioGraph* 1000
# DBA_2J BioGraph* 10000
# DBA_2J breakdancer 10
# DBA_2J breakdancer 100
# DBA_2J breakdancer 1000
# DBA_2J breakdancer 10000
# DBA_2J clever 10
# DBA_2J clever 100
# DBA_2J clever 1000
# DBA_2J clever 10000
# DBA_2J delly 10
# DBA_2J delly 100
# DBA_2J delly 1000
# DBA_2J delly 10000
# DBA_2J gasv 10
# DBA_2J gasv 100
# DBA_2J gasv 1000
# DBA_2J gasv 10000
# DBA_2J gridss 10
# DBA_2J gridss 100
# DBA_2J gridss 1000
# DBA_2J gridss 10000
# DBA_2J indelminer 10
# DBA_2J indelminer 100
# DBA_2J indelminer 1000
# DBA_2J indelminer 10000
# DBA_2J lumpexpress 10
# DBA_2J lumpexpress 100
# DBA_2J lumpexpress 1000
# DBA_2J lumpexpress 10000
# DBA_2J mistrvar 10
# DBA_2J mistrvar 100
# DBA_2J mistrvar 1000
# DBA_2J mistrvar 10000
# DBA_2J pindel 10
# DBA_2J pindel 100
# DBA_2J pindel 1000
# DBA_2J pindel 10000
# DBA_2J platypus 10
# DBA_2J platypus 100
# DBA_2J platypus 1000
# DBA_2J platypus 10000
# DBA_2J popdel 10
# DBA_2J popdel 100
# DBA_2J popdel 1000
# DBA_2J popdel 10000
# DBA_2J rdxplorer 10
# DBA_2J rdxplorer 100
# DBA_2J rdxplorer 1000
# DBA_2J rdxplorer 10000
# DBA_2J smoove 10
# DBA_2J smoove 100
# DBA_2J smoove 1000
# DBA_2J smoove 10000
# DBA_2J sniffles 10
# DBA_2J sniffles 100
# DBA_2J sniffles 1000
# DBA_2J sniffles 10000
# LP_J BioGraph* 10
# LP_J BioGraph* 100
# LP_J BioGraph* 1000
# LP_J BioGraph* 10000
# LP_J breakdancer 10
# LP_J breakdancer 100
# LP_J breakdancer 1000
# LP_J breakdancer 10000
# LP_J clever 10
# LP_J clever 100
# LP_J clever 1000
# LP_J clever 10000
# LP_J delly 10
# LP_J delly 100
# LP_J delly 1000
# LP_J delly 10000
# LP_J gasv 10
# LP_J gasv 100
# LP_J gasv 1000
# LP_J gasv 10000
# LP_J gridss 10
# LP_J gridss 100
# LP_J gridss 1000
# LP_J gridss 10000
# LP_J indelminer 10
# LP_J indelminer 100
# LP_J indelminer 1000
# LP_J indelminer 10000
# LP_J lumpexpress 10
# LP_J lumpexpress 100
# LP_J lumpexpress 1000
# LP_J lumpexpress 10000
# LP_J mistrvar 10
# LP_J mistrvar 100
# LP_J mistrvar 1000
# LP_J mistrvar 10000
# LP_J pindel 10
# LP_J pindel 100
# LP_J pindel 1000
# LP_J pindel 10000
# LP_J platypus 10
# LP_J platypus 100
# LP_J platypus 1000
# LP_J platypus 10000
# LP_J popdel 10
# LP_J popdel 100
# LP_J popdel 1000
# LP_J popdel 10000
# LP_J rdxplorer 10
# LP_J rdxplorer 100
# LP_J rdxplorer 1000
# LP_J rdxplorer 10000
# LP_J smoove 10
# LP_J smoove 100
# LP_J smoove 1000
# LP_J smoove 10000
# LP_J sniffles 10
# LP_J sniffles 100
# LP_J sniffles 1000
# LP_J sniffles 10000
# (117, 4)

# %%
for s in strain:
    for t in tools:
        for th in [10,100,1000,10000]:
            if not (((group_data_TN['tool'] == t) & (group_data_TN['strain'] == s) & (group_data_TN['threshold'] == th)).any()):
                group_data_TN = group_data_TN.append({'tool' : t , 'strain' : s,'threshold' : th,'nTN' : 0} , ignore_index=True)
                #print (s,t,th)
group_data_TN.shape
# Out:
# (420, 4)

# %%
#merge TP and FP
df_merge=pd.merge(group_data_TP, group_data_FP,on=['tool','threshold','strain'])
df_merge=pd.merge(df_merge, group_data_TN,on=['tool','threshold','strain'])
df_merge.shape
# Out:
# (117, 6)

# %%
df_merge.head(10)
# Out:
#           tool  threshold   strain  nTP   nFP  nTN
# 0    BioGraph*         10    AKR_J   72   778   11
# 1    BioGraph*         10      A_J   94   842   20
# 2    BioGraph*         10  BALB_CJ   90   834   13
# 3    BioGraph*       1000    AKR_J  269   156  122
# 4    BioGraph*       1000      A_J  304   164  150
# 5    BioGraph*       1000  BALB_CJ  294   168  139
# 6    BioGraph*      10000    AKR_J  291   134  173
# 7    BioGraph*      10000      A_J  323   145  198
# 8    BioGraph*      10000  BALB_CJ  317   145  196
# 9  breakdancer         10    AKR_J   18  1054    4

# %%
#true SV deletions
df_current = pd.DataFrame(columns=['strain','length'])
df = pd.DataFrame(columns=['strain','length'])


for s in strain:
    file='../gold_standard/mouse_vcf/'+s+'_reference.vcf'
    callset = allel.read_vcf(file,fields='*')
    
    df_current = pd.DataFrame({'strain': s, 'length': callset['variants/SVLEN']})
    df = pd.concat([df_current, df],ignore_index=True)
group_data_true = df.groupby(['strain'],as_index=False).count()
group_data_true=group_data_true.rename(columns={"length": "n_true"})
group_data_true
# Out:
#     strain  n_true
# 0    AKR_J     504
# 1      A_J     533
# 2  BALB_CJ     545
# 3  C3H_HeJ     539
# 4    CBA_J     586
# 5   DBA_2J     609
# 6     LP_J     483

# %%
df_merge=pd.merge(df_merge, group_data_true)
df_merge.shape
# Out:
# (117, 7)

# %% [markdown]
# ## Calculating precision, sensitivity, specificity, f-score

# %%
df_merge['nFN']=df_merge['n_true']-df_merge['nTP']

df_merge['sensitivity']=df_merge['nTP']/df_merge['n_true']
df_merge['precision']=df_merge['nTP']/(df_merge['nTP']+df_merge['nFP'])
df_merge['specificity']=df_merge['nTN']/(df_merge['nTN']+df_merge['nFP'])
df_merge['f-score']=2*(df_merge['sensitivity']*df_merge['precision'])/(df_merge['sensitivity']+df_merge['precision']+0.00000001)
df_merge.head()
# Out:
#           tool  threshold strain  nTP   nFP  nTN  n_true  nFN  sensitivity  \
# 0    BioGraph*         10  AKR_J   72   778   11     504  432     0.142857
# 1    BioGraph*       1000  AKR_J  269   156  122     504  235     0.533730
# 2    BioGraph*      10000  AKR_J  291   134  173     504  213     0.577381
# 3  breakdancer         10  AKR_J   18  1054    4     504  486     0.035714
# 4  breakdancer       1000  AKR_J  311   225  166     504  193     0.617063
#
#    precision  specificity   f-score
# 0   0.084706     0.013942  0.106352
# 1   0.632941     0.438849  0.579117
# 2   0.684706     0.563518  0.626480
# 3   0.016791     0.003781  0.022843
# 4   0.580224     0.424552  0.598077

# %%
#count number of TP/FP/TN/FN for each tool at each threshold
df_sum=df_merge.groupby(['tool','threshold'],as_index=False)['nTP','nFP','nFN','nTN'].sum()
df_sum.head(10)
# Out:
#           tool  threshold   nTP    nFP   nFN  nTN
# 0    BioGraph*         10   256   2454  1326   44
# 1    BioGraph*       1000   867    488   715  411
# 2    BioGraph*      10000   931    424   651  567
# 3  breakdancer         10    56   3192  1526   13
# 4  breakdancer       1000  1026    598   556  567
# 5  breakdancer      10000  1070    554   512  727
# 6       clever         10   380  21212  1202   80
# 7       clever       1000  1244   9552   338  615
# 8       clever      10000  1365   9431   217  859
# 9        delly         10   440   5146  1142   75

# %%
# %store df_sum
# Out:
# Stored 'df_sum' (DataFrame)
# UsageError: Unknown variable 'nTP'
