# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_all_len=pd.read_csv('../analysis_files/df_all_len.csv')
df_all_len.head(50)
# Out:
#     Unnamed: 0       tool  threshold   strain       len  n_true  nTP  nFP  \
# 0            0  BioGraph*         10    AKR_J     1000+   140.0   10   77
# 1            1  BioGraph*         10      A_J     1000+   158.0   13   94
# 2            2  BioGraph*         10  BALB_CJ     1000+   157.0   14   95
# 3            3  BioGraph*         10  C3H_HeJ     1000+   149.0   11   81
# 4            4  BioGraph*         10    CBA_J     1000+   144.0    9   82
# 5            5  BioGraph*         10   DBA_2J     1000+   149.0   11   90
# 6            6  BioGraph*         10     LP_J     1000+   139.0   15   75
# 7            7  BioGraph*        100    AKR_J     1000+   140.0   72   15
# 8            8  BioGraph*        100    AKR_J  500-1000    83.0   28    4
# 9            9  BioGraph*        100      A_J     1000+   158.0   87   20
# 10          10  BioGraph*        100      A_J  500-1000    74.0   26    6
# 11          11  BioGraph*        100  BALB_CJ     1000+   157.0   85   24
# 12          12  BioGraph*        100  BALB_CJ  500-1000    77.0   25    5
# 13          13  BioGraph*        100  C3H_HeJ     1000+   149.0   76   16
# 14          14  BioGraph*        100  C3H_HeJ  500-1000    80.0   23    7
# 15          15  BioGraph*        100    CBA_J     1000+   144.0   75   16
# 16          16  BioGraph*        100    CBA_J  500-1000    87.0   23    6
# 17          17  BioGraph*        100   DBA_2J     1000+   149.0   82   19
# 18          18  BioGraph*        100   DBA_2J  500-1000    91.0   22    8
# 19          19  BioGraph*        100     LP_J     1000+   139.0   78   12
# 20          20  BioGraph*        100     LP_J  500-1000    70.0   19    3
# 21          21  BioGraph*       1000    AKR_J     1000+   140.0   73   14
# 22          22  BioGraph*       1000    AKR_J  500-1000    83.0   29    3
# 23          23  BioGraph*       1000      A_J     1000+   158.0   90   17
# 24          24  BioGraph*       1000      A_J  500-1000    74.0   29    3
# 25          25  BioGraph*       1000  BALB_CJ     1000+   157.0   88   21
# 26          26  BioGraph*       1000  BALB_CJ  500-1000    77.0   28    2
# 27          27  BioGraph*       1000  C3H_HeJ     1000+   149.0   77   15
# 28          28  BioGraph*       1000  C3H_HeJ  500-1000    80.0   25    5
# 29          29  BioGraph*       1000    CBA_J     1000+   144.0   76   15
# 30          30  BioGraph*       1000    CBA_J  500-1000    87.0   25    4
# 31          31  BioGraph*       1000   DBA_2J     1000+   149.0   83   18
# 32          32  BioGraph*       1000   DBA_2J  500-1000    91.0   26    4
# 33          33  BioGraph*       1000     LP_J     1000+   139.0   79   11
# 34          34  BioGraph*       1000     LP_J  500-1000    70.0   21    1
# 35          35  BioGraph*      10000    AKR_J   100-500   234.0  142   30
# 36          36  BioGraph*      10000    AKR_J     1000+   140.0   74   13
# 37          37  BioGraph*      10000    AKR_J  500-1000    83.0   28    4
# 38          38  BioGraph*      10000      A_J   100-500   249.0  162   29
# 39          39  BioGraph*      10000      A_J     1000+   158.0   90   17
# 40          40  BioGraph*      10000      A_J  500-1000    74.0   28    4
# 41          41  BioGraph*      10000  BALB_CJ   100-500   260.0  155   22
# 41    1  105.0     0.596154   0.875706     0.043478  0.709382
# 42  190   71.0     0.547771   0.788991     0.892019  0.646617
# 43    3   50.0     0.350649   0.900000     0.500000  0.504673
# 44    1  116.0     0.565543   0.838889     0.033333  0.675615
# 45  172   73.0     0.510067   0.826087     0.914894  0.630705
# 46    4   56.0     0.300000   0.800000     0.400000  0.436364
# 47    1  134.0     0.559211   0.862944     0.035714  0.678643
# 48  184   69.0     0.520833   0.824176     0.920000  0.638298
# 49    4   63.0     0.275862   0.827586     0.444444  0.413793

# %%
threshold_100=df_all_len[(df_all_len['threshold'] ==100)]
threshold_100
# Out:
#      Unnamed: 0       tool  threshold   strain       len  n_true  nTP  nFP  \
# 7             7  BioGraph*        100    AKR_J     1000+   140.0   72   15
# 8             8  BioGraph*        100    AKR_J  500-1000    83.0   28    4
# 9             9  BioGraph*        100      A_J     1000+   158.0   87   20
# 10           10  BioGraph*        100      A_J  500-1000    74.0   26    6
# 11           11  BioGraph*        100  BALB_CJ     1000+   157.0   85   24
# ..          ...        ...        ...      ...       ...     ...  ...  ...
# 766         766   sniffles        100  C3H_HeJ     1000+   149.0   42    6
# 767         767   sniffles        100    CBA_J     1000+   144.0   45   12
# 768         768   sniffles        100    CBA_J  500-1000    87.0   11    1
# 769         769   sniffles        100   DBA_2J     1000+   149.0   52    3
# 770         770   sniffles        100     LP_J     1000+   139.0   48    9
#
#      nTN    nFN  sensitivity  precision  specificity   f-score
# 7    105   68.0     0.514286   0.827586     0.875000  0.634361
# 8      3   55.0     0.337349   0.875000     0.428571  0.486957
# 9    129   71.0     0.550633   0.813084     0.865772  0.656604
# 10     2   48.0     0.351351   0.812500     0.250000  0.490566
# 11   120   72.0     0.541401   0.779817     0.833333  0.639098
# ..   ...    ...          ...        ...          ...       ...
# 766   49  107.0     0.281879   0.875000     0.890909  0.426396
# 767   62   99.0     0.312500   0.789474     0.837838  0.447761
# 768    1   76.0     0.126437   0.916667     0.500000  0.222222
# 769   48   97.0     0.348993   0.945455     0.941176  0.509804
# 770   23   91.0     0.345324   0.842105     0.718750  0.489796
#
# [183 rows x 14 columns]

# %% [markdown]
# # Figure 4a

# %%
# %store -r

fig4a=sns.set_style("white")
fig4a=sns.set_context("talk")
fig4a = sns.catplot(x="cat", y="n",data=df_cat,kind='bar',aspect=1.5,palette="Greys")
fig4a.set(xlabel='Deletion length', ylabel='Number of deletions')
fig4a=sns.despine()

plt.savefig("../figures/fig4/fig4a", bbox_inches='tight')
plt.savefig("../figures/fig4/fig4a.pdf",bbox_inches="tight")

# %%
#plot = df_cat.plot.pie(y='n', figsize=(5, 5))
import matplotlib.pyplot as plt

labels = '50-100 bp', '100-500 bp', '500-1000 bp', '>1000 bp'
sizes = [255, 1857, 562, 1036]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')
plt.show()

plt.savefig("../figures/fig4/fig4a_pie", bbox_inches='tight')
plt.savefig("../figures/fig4/fig4a_pie.pdf",bbox_inches="tight")

# %% [markdown]
# # Figure 4b

# %%
fig4b=sns.set_style('white')
fig4b=sns.set_context('talk')

fig_order=['gasv','rdxplorer','breakdancer','pindel','clever','mistrvar','popdel','gridss','BioGraph*','delly','indelminer','smoove','lumpexpress','sniffles']
pal = []
for tool in fig_order:
        pal.append(color_map[tool])

fig4b = sns.catplot(x='len', y='sensitivity',data=threshold_100,hue='tool',errwidth=2.5,aspect=1.8,kind='bar',palette=pal,hue_order=fig_order)
fig4b.set_xticklabels(rotation=0)
fig4b.set(ylim=(0, 1))
fig4b.set(xlabel='Deletion Length (bp)', ylabel='Sensitivity')

fig4b=sns.despine()
#plt.show(fig4b)

plt.savefig("../figures/fig4/fig4b", bbox_inches='tight')
plt.savefig("../figures/fig4/fig4b.pdf",bbox_inches="tight")

# %% [markdown]
# # Figure 4c

# %%
fig4c=sns.set_style('white')
fig4c=sns.set_context('talk')

fig_order=['gasv','rdxplorer','breakdancer','pindel','clever','mistrvar','popdel','gridss','BioGraph*','delly','indelminer','smoove','lumpexpress','sniffles']
for tool in fig_order:
    pal.append(color_map[tool])

fig4c = sns.catplot(x="len", y="precision",data=all_100_th,hue='tool',errwidth=2.5,aspect=1.8,kind='bar',palette=pal,hue_order=fig_order)
fig4c.set_xticklabels(rotation=0)
fig4c.set(xlabel='Deletion Length (bp)', ylabel='Precision')
fig4c=sns.despine()
#plt.show(fig4c)
plt.savefig("../figures/fig4/fig4c", bbox_inches='tight')
plt.savefig("../figures/fig4/fig4c.pdf",bbox_inches="tight")

# %% [markdown]
# # Figure 4d

# %%
fig4d=sns.set_style("white")
fig4d=sns.set_context("talk")

fig_order=['gasv','rdxplorer','pindel','mistrvar','indelminer','breakdancer','clever','gridss','delly','BioGraph*','popdel','lumpexpress','smoove','sniffles']
pal = []
for tool in fig_order:
    pal.append(color_map[tool])

fig4d = sns.catplot(x="len", y="f-score",data=all_100_th,hue='tool',aspect=1.8,kind='bar',errwidth=2.5,palette=pal,hue_order=fig_order)
fig4d.set_xticklabels(rotation=0)
fig4d.set(ylim=(0, 1))
fig4d.set(xlabel='Deletion Length (bp)', ylabel='F-score')
fig4d=sns.despine()
#plt.show(fig4d)

plt.savefig("../figures/fig4/fig4d", bbox_inches='tight')
plt.savefig("../figures/fig4/fig4d.pdf",bbox_inches="tight")

# %% [markdown]
# # Figure 4e

# %%
fig4e=sns.set_style("white")
fig4e=sns.set_context("talk")

fig_order=['rdxplorer','gasv','clever','BioGraph*','sniffles','mistrvar','delly','lumpexpress','smoove','gridss','popdel','indelminer','pindel']
pal = []
for tool in fig_order:
    pal.append(color_map[tool])
    
fig4e = sns.catplot(x="len", y="specificity",data=all_100_th,hue='tool',aspect=1.8,kind='bar',errwidth=2.5,hue_order=fig_order, palette=pal)
fig4e.set_xticklabels(rotation=0)
fig4e.set(xlabel='Deletion Length (bp)', ylabel='Specificity')
fig4e=sns.despine()
#plt.show(g)
plt.savefig("../figures/fig4/fig4e", bbox_inches='tight')
plt.savefig("../figures/fig4/fig4e.pdf",bbox_inches="tight")
