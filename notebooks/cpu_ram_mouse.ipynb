# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../cpu.ram.stats/cpu_mouse.csv")

# %%
data
# Out:
#            Tool sample_name coverage     time     memory
# 0   breakdancer         A_J       1x     1.00    225.680
# 1   breakdancer         A_J      64x     1.00    225.676
# 2   breakdancer     BALB_cJ       1x     2.00    310.918
# 3   breakdancer     BALB_cJ      64x     1.00    320.258
# 4          gasv         A_J       1x     6.00  10307.000
# 5          gasv         A_J      64x   304.00  11104.000
# 6          gasv     BALB_cJ       1x     5.00  10307.000
# 7          gasv     BALB_cJ      64x   551.00  12632.000
# 8        popDEL         A_J       1x     2.68      6.572
# 9        popDEL         A_J      64x     9.05      9.320
# 10       popDEL     BALB_cJ       1x     2.88      8.156
# 11       popDEL     BALB_cJ      64x    10.49      8.784
# 12       smoove         A_J       1x    11.86    244.272
# 13       smoove         A_J      64x    95.71    244.456
# 14       smoove     BALB_cJ       1x    13.89    244.612
# 15       smoove     BALB_cJ      64x   114.47    244.564
# 16     mistrvar         A_J       1x    57.37    902.812
# 17     mistrvar         A_J      64x  2939.84   3073.916
# 18     mistrvar     BALB_cJ       1x    68.09    983.292
# 19     mistrvar     BALB_cJ      64x  3387.34   4419.696
# 20      pindel          A_J       1x    19.00    856.203
# 21      pindel          A_J      64x   990.00   1236.000
# 22      pindel      BALB_cJ       1x    22.00    856.602
# 23      pindel      BALB_cJ      64x  1047.00   1403.000
# 24       clever         A_J       1x    24.00    795.758
# 25       clever         A_J      64x  3510.00    872.949
# 26       clever     BALB_cJ       1x    27.00    795.758
# 27       clever     BALB_cJ      64x  1915.00    886.273

# %%
# gasv takes the longest, the two samples show similar behavior
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="sample_name", y="time",data=data,hue='Tool',aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Sample', ylabel='Run time (seconds)',yscale="log")
g=sns.despine()
plt.savefig('FigS20_time_sample.png')
plt.show(g)

# %%
# gasv takes the most memory, the two samples show similar behavior
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="sample_name", y="memory",data=data,hue='Tool',aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Sample', ylabel='Memory (MB)',yscale="log")
g=sns.despine()
plt.savefig('FigS20_memory_sample.png')
plt.show(g)

# %%
#Time taken by 1x is negligible as compared to full coverage sample 
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="time",data=data,hue='coverage',aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools', ylabel='Run time (seconds)',yscale="log")
g=sns.despine()
plt.savefig('FigS20_time_coverage.png')
plt.show(g)

# %%
#Memory for full coverage and 1x is comparable 
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="memory",data=data,hue='coverage',aspect=1.8,kind='bar',capsize=.1,errwidth=3)
g.set(xlabel='Tools', ylabel='Memory (MB)',yscale="log")
g=sns.despine()
plt.savefig('FigS20_memory_coverage.png')
plt.show(g)

# %%
#only contains coverage from 1x 
data_1x=data.loc[data['coverage'] == "1x"]
#only contains coverage from 64x 
data_64x=data.loc[data['coverage'] == "64x"]

# %%
data_1x
# Out:
#            Tool sample_name coverage   time     memory
# 0   breakdancer         A_J       1x   1.00    225.680
# 2   breakdancer     BALB_cJ       1x   2.00    310.918
# 4          gasv         A_J       1x   6.00  10307.000
# 6          gasv     BALB_cJ       1x   5.00  10307.000
# 8        popDEL         A_J       1x   2.68      6.572
# 10       popDEL     BALB_cJ       1x   2.88      8.156
# 12       smoove         A_J       1x  11.86    244.272
# 14       smoove     BALB_cJ       1x  13.89    244.612
# 16     mistrvar         A_J       1x  57.37    902.812
# 18     mistrvar     BALB_cJ       1x  68.09    983.292
# 20      pindel          A_J       1x  19.00    856.203
# 22      pindel      BALB_cJ       1x  22.00    856.602
# 24       clever         A_J       1x  24.00    795.758
# 26       clever     BALB_cJ       1x  27.00    795.758

# %%
#Variation of time for 1x with tool
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="time",data=data_1x,aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools (1x Coverage)', ylabel='Run time (seconds)',yscale="log")
g=sns.despine()
plt.savefig('FigS20_runtime_tools_1x.png')
plt.show(g)

# %%
#Variation of memory for 1x with tool
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="memory",data=data_1x,aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools (1x Coverage)', ylabel='Memory (MB)',yscale="log")
g=sns.despine()
plt.savefig('FigS20_memory_tools_1x.png')
plt.show(g)

# %%
data_64x
# Out:
#            Tool sample_name coverage     time     memory
# 1   breakdancer         A_J      64x     1.00    225.676
# 3   breakdancer     BALB_cJ      64x     1.00    320.258
# 5          gasv         A_J      64x   304.00  11104.000
# 7          gasv     BALB_cJ      64x   551.00  12632.000
# 9        popDEL         A_J      64x     9.05      9.320
# 11       popDEL     BALB_cJ      64x    10.49      8.784
# 13       smoove         A_J      64x    95.71    244.456
# 15       smoove     BALB_cJ      64x   114.47    244.564
# 17     mistrvar         A_J      64x  2939.84   3073.916
# 19     mistrvar     BALB_cJ      64x  3387.34   4419.696
# 21      pindel          A_J      64x   990.00   1236.000
# 23      pindel      BALB_cJ      64x  1047.00   1403.000
# 25       clever         A_J      64x  3510.00    872.949
# 27       clever     BALB_cJ      64x  1915.00    886.273

# %%
#Variation of time for 1x with tool
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="time",data=data_64x,aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools (64x Coverage)', ylabel='Run time (seconds)',yscale="log")
g=sns.despine()
plt.savefig('FigS20_runtime_tools_64x.png')
plt.show(g)

# %%
#Variation of memory for 1x with tool
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Tool", y="memory",data=data_64x,aspect=1.8,kind='bar',capsize=.1,errwidth=3)

g.set(xlabel='Tools (64x Coverage)', ylabel='Memory (MB)',yscale="log")
g=sns.despine()
plt.savefig('FigS20_memory_tools_64x.png')
plt.show(g)
